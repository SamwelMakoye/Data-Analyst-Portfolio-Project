# %%
#IMPORTING THE NECESSARY LIBRARIES
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set_theme()

# %%
#IMPORT THE DATA
spotify_youtube = pd.read_csv(r'C:\Users\Samwel\OneDrive\Desktop\English Lesson Notes\Spotify_Youtube.csv')
spotify_youtube
# Out:
#        Unnamed: 0       Artist  \
# 0               0     Gorillaz
# 1               1     Gorillaz
# 2               2     Gorillaz
# 3               3     Gorillaz
# 4               4     Gorillaz
# ...           ...          ...
# 20713       20713  SICK LEGEND
# 20714       20714  SICK LEGEND
# 20715       20715  SICK LEGEND
# 20716       20716  SICK LEGEND
# 20717       20717  SICK LEGEND
#
#                                              Url_spotify  \
# 0      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4      https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...                                                  ...
# 20713  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# ...

# %%
#CREATE A COPY OF THE DATA
spotify_youtube_data = spotify_youtube.copy()

# %%
spotify_youtube_data.head()
# Out:
#    Unnamed: 0    Artist                                        Url_spotify  \
# 0           0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1           1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2           2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3           3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4           4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# ...

# %%
#REMOVE THE UNNNAMED COLUMN
spotify_youtube_data.columns
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
spotify_youtube_data.drop('Unnamed: 0', axis = 1, inplace = True)

# %%
spotify_youtube_data.head()
# Out:
#      Artist                                        Url_spotify  \
# 0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
#
#                                            Track  \
# 0                                 Feel Good Inc.
# 1                                Rhinestone Eyes
# 2  New Gold (feat. Tame Impala and Bootie Brown)
# 3                             On Melancholy Hill
# 4                                 Clint Eastwood
#
#                                            Album Album_type  \
# 0                                     Demon Days      album
# 1                                  Plastic Beach      album
# 2  New Gold (feat. Tame Impala and Bootie Brown)     single
# ...

# %%
#EXTRACT SOME BASIC INFO FROM THE DATA

# %%
spotify_youtube_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20718 entries, 0 to 20717
# Data columns (total 27 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            20718 non-null  object
#  1   Url_spotify       20718 non-null  object
#  2   Track             20718 non-null  object
#  3   Album             20718 non-null  object
#  4   Album_type        20718 non-null  object
#  5   Uri               20718 non-null  object
#  6   Danceability      20716 non-null  float64
#  7   Energy            20716 non-null  float64
#  8   Key               20716 non-null  float64
#  9   Loudness          20716 non-null  float64
#  10  Speechiness       20716 non-null  float64
#  11  Acousticness      20716 non-null  float64
#  12  Instrumentalness  20716 non-null  float64
#  13  Liveness          20716 non-null  float64
#  14  Valence           20716 non-null  float64
#  15  Tempo             20716 non-null  float64
# ...

# %%
spotify_youtube_data.describe()
# Out:
#        Danceability        Energy           Key      Loudness   Speechiness  \
# count  20716.000000  20716.000000  20716.000000  20716.000000  20716.000000
# mean       0.619777      0.635250      5.300348     -7.671680      0.096456
# std        0.165272      0.214147      3.576449      4.632749      0.111960
# min        0.000000      0.000020      0.000000    -46.251000      0.000000
# 25%        0.518000      0.507000      2.000000     -8.858000      0.035700
# 50%        0.637000      0.666000      5.000000     -6.536000      0.050500
# 75%        0.740250      0.798000      8.000000     -4.931000      0.103000
# max        0.975000      1.000000     11.000000      0.920000      0.964000
#
#        Acousticness  Instrumentalness      Liveness       Valence  \
# count  20716.000000      20716.000000  20716.000000  20716.000000
# mean       0.291535          0.055962      0.193521      0.529853
# std        0.286299          0.193262      0.168531      0.245441
# ...

# %% [markdown]
# # ARTIST

# %%
spotify_youtube_data['Artist'].unique()
# Out:
# array(['Gorillaz', 'Red Hot Chili Peppers', '50 Cent', ..., 'LE SSERAFIM',
#        'ThxSoMch', 'SICK LEGEND'], dtype=object)

# %%
spotify_youtube_data['Artist'].nunique()
# Out:
# 2079

# %%
#VIEW SOME OF THE ARTIST WITH LEAST TRACKS
spotify_youtube_data['Artist'].value_counts().tail(15)
# Out:
# Antonio Vivaldi      9
# Tony Dize            9
# Lil' Kim             9
# JIN                  8
# Jung Kook            7
# dazy                 7
# Miggy Dela Rosa      7
# Ananya Bhat          7
# FIFA Sound           7
# Shubh                6
# NewJeans             6
# Alfonso Herrera      6
# Jimin                3
# Stars Music Chile    1
# Bootie Brown         1
# Name: Artist, dtype: int64

# %% [markdown]
# # TRACK

# %%
spotify_youtube_data['Track'].nunique()
# Out:
# 17841

# %%
#DROP SOME DUPLICATES FROM THE DATA IF ANY
spotify_youtube_data.drop_duplicates()
# Out:
#             Artist                                        Url_spotify  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20713  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  SICK LEGEND  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %% [markdown]
# #SEEMS THERE ARE NO DUPLICATES

# %%
#CONVERT THE STRINGS IN Artist, Track and Album to lower case with capital beginnings
spotify_youtube_data['Artist'] = spotify_youtube_data['Artist'].str.title()
spotify_youtube_data['Track'] = spotify_youtube_data['Track'].str.title()
spotify_youtube_data['Album'] = spotify_youtube_data['Album'].str.title()
spotify_youtube_data['Title'] = spotify_youtube_data['Title'].str.title()
spotify_youtube_data['Channel'] = spotify_youtube_data['Channel'].str.title()

# %%
spotify_youtube_data
# Out:
#             Artist                                        Url_spotify  \
# 0         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4         Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...            ...                                                ...
# 20713  Sick Legend  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20714  Sick Legend  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20715  Sick Legend  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20716  Sick Legend  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
# 20717  Sick Legend  https://open.spotify.com/artist/3EYY5FwDkHEYLw...
#
#                                                Track  \
# 0                                     Feel Good Inc.
# ...

# %%
#CHECK FOR CORRELATION AMONG NUMERIC VALUES
plt.figure(figsize=(16,8))
sns.heatmap(data = spotify_youtube_data[['Danceability','Energy','Key','Loudness','Speechiness',
                                        'Acousticness','Views','Likes','Comments','Stream']].corr(),
            annot = True,
           cmap = 'viridis')
# Out:
# <AxesSubplot:>

# %%
spotify_youtube_data.columns
# Out:
# Index(['Artist', 'Url_spotify', 'Track', 'Album', 'Album_type', 'Uri',
#        'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
spotify_youtube_data[spotify_youtube_data['Track'] == spotify_youtube_data['Album']].count()
# Out:
# Artist              3965
# Url_spotify         3965
# Track               3965
# Album               3965
# Album_type          3965
# Uri                 3965
# Danceability        3965
# Energy              3965
# Key                 3965
# Loudness            3965
# Speechiness         3965
# Acousticness        3965
# Instrumentalness    3965
# Liveness            3965
# Valence             3965
# Tempo               3965
# Duration_ms         3965
# Url_youtube         3877
# Title               3877
# Channel             3877
# Views               3877
# Likes               3871
# Comments            3865
# Description         3833
# Licensed            3877
# official_video      3877
# Stream              3881
# dtype: int64

# %% [markdown]
# # ALBUM TYPE

# %%
spotify_youtube_data['Album_type'].value_counts()
# Out:
# album          14926
# single          5004
# compilation      788
# Name: Album_type, dtype: int64

# %%
plt.hist(spotify_youtube_data['Album_type'],
         bins = 3)
plt.show()

# %%
spotify_youtube_data['Danceability'].dtype
# Out:
# dtype('float64')

# %%
# DISPLAYING ALL COLUMNS
pd.set_option('display.max_columns', None)

# %%
spotify_youtube_data[spotify_youtube_data['Danceability'].isnull()]
# Out:
#                        Artist  \
# 11890     Natasha Bedingfield
# 13843  White Noise For Babies
#
#                                              Url_spotify  \
# 11890  https://open.spotify.com/artist/7o95ZoZt5ZYn31...
# 13843  https://open.spotify.com/artist/4ZfEELHfyKd4od...
#
#                            Track  \
# 11890                These Words
# 13843  Rain In The Early Morning
#
#                                                    Album Album_type  \
# 11890                                          Unwritten      album
# 13843  Soothing Rain For Background Sounds And Natura...      album
#
#                                         Uri  Danceability  Energy  Key  \
# 11890  spotify:track:6MFQeWtk7kxWGydnJB2y36           NaN     NaN  NaN
# 13843  spotify:track:4juc1w1fGFn8CxKp8gGThc           NaN     NaN  NaN
#
#        Loudness  Speechiness  Acousticness  Instrumentalness  Liveness  \
# 11890       NaN          NaN           NaN               NaN       NaN
# ...

# %%
#SEARCHING ANY RELATION WITH OTHER ATTRIBUTES
spotify_youtube_data[spotify_youtube_data['Artist'] == 'Natasha Bedingfield'][['Danceability','Album','Energy','Tempo','Stream',
                                                                              'Views']]
# Out:
#        Danceability                                              Album  \
# 11888         0.706                                          Unwritten
# 11889         0.721                              Pocketful Of Sunshine
# 11890           NaN                                          Unwritten
# 11891         0.614  Shake Up Christmas 2011 (Official Coca-Cola Ch...
# 11892         0.781                              Pocketful Of Sunshine
# 11893         0.377                             Love Song To The Earth
# 11894         0.486                                               N.B.
# 11895         0.407                                          Unwritten
# 11896         0.626                    The Music From The Pirate Fairy
# 11897         0.621                                          Unwritten
#
#        Energy    Tempo       Stream        Views
# 11888   0.800  100.011  482619005.0  113675457.0
# 11889   0.880  110.021  196974484.0   76280054.0
# ...

# %%
formatted_mean = round(spotify_youtube_data[(spotify_youtube_data['Artist'] == 'Natasha Bedingfield') & (spotify_youtube_data['Album'] == 'Unwritten')]['Danceability'].mean(), 3)

# %%
formatted_mean
# Out:
# 0.578

# %%
#SEEMS THE TWO MISS QUITE SOME VALUES FROM OTHER COLUMNS, SO WE DROP THEM

# %%
spotify_youtube_data.dropna(subset='Danceability', inplace = True)

# %%
spotify_youtube_data.isnull().sum()
# Out:
# Artist                0
# Url_spotify           0
# Track                 0
# Album                 0
# Album_type            0
# Uri                   0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Url_youtube         469
# Title               469
# Channel             469
# Views               469
# Likes               540
# Comments            568
# Description         875
# Licensed            469
# official_video      469
# Stream              576
# dtype: int64

# %%
#DROP SOME COLUMNS THAT ARE NOT NEEDED
spotify_youtube_data.drop(['Url_spotify', 'Uri', 'Url_youtube', 'Title', 'Description'], axis = 1, inplace = True)

# %%
spotify_youtube_data.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Channel             469
# Views               469
# Likes               540
# Comments            568
# Licensed            469
# official_video      469
# Stream              576
# dtype: int64

# %%
spotify_youtube_data['Channel'].value_counts()
# Out:
# T-Series                238
# Sonymusicindiavevo       95
# Sonymusicsouthvevo       83
# Zee Music Company        65
# Rhino                    62
#                        ...
# Decca Classics            1
# Lucianopavarottivevo      1
# G.Jerry Louison           1
# Rosa Maria                1
# Viva Same Difference      1
# Name: Channel, Length: 6708, dtype: int64

# %%
#FILLING THE NULLS WITH EMPTY SPACE
spotify_youtube_data['Channel'].fillna('', inplace = True)

# %%
spotify_youtube_data.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Channel               0
# Views               469
# Likes               540
# Comments            568
# Licensed            469
# official_video      469
# Stream              576
# dtype: int64

# %% [markdown]
# # VIEWS

# %%
spotify_youtube_data['Views'].isnull().value_counts()
# Out:
# False    20247
# True       469
# Name: Views, dtype: int64

# %%
spotify_youtube_data[spotify_youtube_data['Views'].isnull()]
# Out:
#                                  Artist                         Track  \
# 410                      Wisin & Yandel                   Besos Moja2
# 411                      Wisin & Yandel               Mayor Que Usted
# 412                      Wisin & Yandel                         Vapor
# 413                      Wisin & Yandel                   Si Te Pillo
# 414                      Wisin & Yandel             Noche De Entierro
# ...                                 ...                           ...
# 20090                Guilherme & Benuto    Pulei Na Piscina - Ao Vivo
# 20091                Guilherme & Benuto                Batom Vermelho
# 20092                Guilherme & Benuto  Declaração Pro Bar - Ao Vivo
# 20093                      Fred Again..                        Rumble
# 20282  Solfeggio Healing Frequencies Mt      528 Hz Emotional Healing
#
#                                              Album Album_type  Danceability  \
# ...

# %%
#DROP THE ROWS
spotify_youtube_data.dropna(subset='Views', inplace = True)

# %%
spotify_youtube_data.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Channel               0
# Views                 0
# Likes                71
# Comments             99
# Licensed              0
# official_video        0
# Stream              556
# dtype: int64

# %% [markdown]
# # LIKES

# %%
spotify_youtube_data[spotify_youtube_data['Likes'].isnull()]['Album'].nunique()
# Out:
# 58

# %%
likes_mean = round(spotify_youtube_data['Likes'].mean(), 0)
likes_mean
# Out:
# 663366.0

# %%
spotify_youtube_data['Likes'].fillna(likes_mean, inplace = True)

# %%
spotify_youtube_data['Likes'].isnull().value_counts()
# Out:
# False    20247
# Name: Likes, dtype: int64

# %% [markdown]
# # COMMENTS

# %%
spotify_youtube_data[spotify_youtube_data['Comments'].isnull()]
# Out:
#                    Artist                                              Track  \
# 970         Bibi Und Tina  Up, Up, Up (Nobody’S Perfect) [Feat. Lina Lari...
# 1557            The Doors                                 People Are Strange
# 1770       The Beach Boys                   Surfin' U.S.A. - Remastered 2001
# 1945            Intocable                                 Estás Que Te Pelas
# 1958        K. S. Chithra                Yeh Haseen Vadiyan Yeh Khula Aasman
# ...                   ...                                                ...
# 19671       Natanael Cano                                       Amor Tumbado
# 19800         Girl In Red                                   I'Ll Die Anyway.
# 19801         Girl In Red                                                4Am
# 20083  Guilherme & Benuto    Haja Colírio (Feat. Hugo & Guilherme) - Ao Vivo
# 20692         Le Sserafim                                        Sour Grapes
#
# ...

# %%
#LETS CHECK THE RELATIONSHIP BETWEEN COMMENTS AND STREAM
plt.figure(figsize=(12, 6))
sns.scatterplot(data = spotify_youtube_data, x = 'Comments',
                y = 'Stream', hue = 'Album_type')
# Out:
# <AxesSubplot:xlabel='Comments', ylabel='Stream'>

# %%
spotify_youtube_data[spotify_youtube_data['Comments'].isnull()]['Album_type'].value_counts()
# Out:
# album          83
# single         13
# compilation     3
# Name: Album_type, dtype: int64

# %%
plt.figure(figsize=(12,6))
plt.bar(x = spotify_youtube_data['Album_type'],
       height = spotify_youtube_data['Comments'])
plt.xticks(rotation = 45)
plt.show()

# %%
#LETS FILL THE MISSING VALUES BASED ON THE ALBUM_TYPE
spotify_youtube_data[spotify_youtube_data['Album_type'] == 'album']['Comments'].mean()
# Out:
# 28196.66281389749

# %%
album_mean = round(spotify_youtube_data[spotify_youtube_data['Album_type'] == 'album']['Comments'].mean(), 0)
album_mean
# Out:
# 28197.0

# %%
plt.figure(figsize=(12, 6))
sns.boxplot(data = spotify_youtube_data,
           x = 'Album_type',
           y = 'Comments')
# Out:
# <AxesSubplot:xlabel='Album_type', ylabel='Comments'>

# %%
single_mean = round(spotify_youtube_data[spotify_youtube_data['Album_type'] == 'single']['Comments'].mean(), 0)
single_mean
# Out:
# 27152.0

# %%
compilation_mean = round(spotify_youtube_data[spotify_youtube_data['Album_type'] == 'compilation']['Comments'].mean(), 0)
compilation_mean
# Out:
# 17007.0

# %%
#FUNCTION TO FILL THE MISSING DATA WITH RESPECTIVE MEAN VALUES
def impute_mean(cols):
    Comments = cols[0]
    Album_type = cols[1]
    
    if pd.isnull(Comments):
        if Album_type == 'album':
            return album_mean
        elif Album_type == 'single':
            return single_mean
        else:
            return compilation_mean
        
    else:
        return Comments

# %%
spotify_youtube_data['Comments'] = spotify_youtube_data[['Comments', 'Album_type']].apply(impute_mean, axis = 1)

# %%
spotify_youtube_data.isnull().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Channel               0
# Views                 0
# Likes                 0
# Comments              0
# Licensed              0
# official_video        0
# Stream              556
# dtype: int64

# %% [markdown]
# # STREAM

# %%
spotify_youtube_data['Stream'].head()
# Out:
# 0    1.040235e+09
# 1    3.100837e+08
# 2    6.306347e+07
# 3    4.346636e+08
# 4    6.172597e+08
# Name: Stream, dtype: float64

# %%
spotify_youtube_data[spotify_youtube_data['Stream'].isnull()]
# Out:
#           Artist                              Track  \
# 30     Metallica         Enter Sandman (Remastered)
# 31     Metallica  Nothing Else Matters (Remastered)
# 32     Metallica     Master Of Puppets (Remastered)
# 34     Metallica        The Unforgiven (Remastered)
# 35     Metallica                   One (Remastered)
# ...          ...                                ...
# 20703   Thxsomch           Imperfect Girl - Sped Up
# 20704   Thxsomch                   Like I'M British
# 20705   Thxsomch        Only Need My Baby! (Smoagt)
# 20706   Thxsomch       How You Always Look So Good?
# 20707   Thxsomch               Runaway (Move Quick)
#
#                                                    Album Album_type  \
# 30                                Metallica (Remastered)      album
# 31                                Metallica (Remastered)      album
# 32         Master Of Puppets (Remastered Deluxe Box Set)      album
# ...

# %%
plt.figure(figsize=(12,6))
sns.barplot(data = spotify_youtube_data,
           x = 'official_video',
           y = 'Stream',
           hue = 'Licensed',
           palette = 'viridis')
# Out:
# <AxesSubplot:xlabel='official_video', ylabel='Stream'>

# %%
sns.barplot(data = spotify_youtube_data,
           x = 'Licensed',
           y = 'Stream',
           hue = 'Album_type')
# Out:
# <AxesSubplot:xlabel='Licensed', ylabel='Stream'>

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data = spotify_youtube_data,
               x = 'Views',
               y = 'Stream',
               hue = 'Album_type')
# Out:
# <AxesSubplot:xlabel='Views', ylabel='Stream'>

# %%
spotify_youtube_data['Album'].nunique()
# Out:
# 11670

# %%
spotify_youtube_data['official_video'].dtype
# Out:
# dtype('O')

# %%
spotify_youtube_data['official_video'] = spotify_youtube_data['official_video'].astype('bool')

# %%
spotify_youtube_data[spotify_youtube_data['official_video'] == True]
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (Feat. Tame Impala And Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  Sick Legend                           Just Dance Hardstyle
# 20714  Sick Legend                 Set Fire To The Rain Hardstyle
# 20715  Sick Legend                      Outside Hardstyle Sped Up
# 20716  Sick Legend                            Only Girl Hardstyle
# 20717  Sick Legend                             Miss You Hardstyle
#
#                                                Album Album_type  Danceability  \
# 0                                         Demon Days      album         0.818
# ...

# %%
official_stream_mean = round(spotify_youtube_data[spotify_youtube_data['official_video'] == True]['Stream'].mean(), 0)

# %%
unofficial_stream_mean = round(spotify_youtube_data[spotify_youtube_data['official_video'] == False]['Stream'].mean(), 0)

# %%
def impute_mean_stream(cols):
    Stream = cols[0]
    official_video= cols[1]
    
    if pd.isnull(Stream):
        if official_video == True :
            return official_stream_mean
        elif official_video == False:
            return unofficial_stream_mean
        
    else:
        return Stream

# %%
spotify_youtube_data['Stream'] = spotify_youtube_data[['Stream', 'official_video']].apply(impute_mean_stream, axis = 1)

# %%
spotify_youtube_data.isnull().sum()
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
len(spotify_youtube_data)
# Out:
# 20247

# %%
def classify_danceability(Danceability):
    for i in range(0, len(spotify_youtube_data) +1):
        if Danceability >= 0 and Danceability <= 0.3:
            return 'A'
        elif Danceability > 0.3 and Danceability <= 0.7:
            return 'B'
        elif Danceability > 0.7:
            return 'C'

# %%
spotify_youtube_data['Danceability'] = spotify_youtube_data['Danceability'].apply(classify_danceability)

# %%
spotify_youtube_data['Danceability'].value_counts()
# Out:
# B    12447
# C     6957
# A      843
# Name: Danceability, dtype: int64

# %%
def classify_energy(Energy):
    for i in range(0, len(spotify_youtube_data) +1):
        if Energy >= 0 and Energy <= 0.3:
            return 'Low Energy'
        elif Energy > 0.3 and Energy <= 0.7:
            return 'Medium Energy'
        elif Energy > 0.7:
            return 'High Energy'

# %%
spotify_youtube_data['Energy'] = spotify_youtube_data['Energy'].apply(classify_energy)

# %%
spotify_youtube_data['Energy'].value_counts()
# Out:
# Medium Energy    9926
# High Energy      8724
# Low Energy       1597
# Name: Energy, dtype: int64

# %%
spotify_youtube_data['Stream'].isnull().sum()
# Out:
# 0

# %%
sns.set_style('white')
plt.figure(figsize=(12,6))
sns.barplot(x = 'Energy', y = 'Stream',
           data = spotify_youtube_data
           )
plt.title('ENERGY VS STREAM', fontsize = 15)
plt.ylabel('STREAM', fontsize = 12)
plt.xlabel('ENERGY LEVEL', fontsize = 12)
sns.despine()

# %% [markdown]
# # CHANNEL

# %%
spotify_youtube_data['Channel'].value_counts()
# Out:
# T-Series                238
# Sonymusicindiavevo       95
# Sonymusicsouthvevo       83
# Zee Music Company        65
# Rhino                    62
#                        ...
# Decca Classics            1
# Lucianopavarottivevo      1
# G.Jerry Louison           1
# Rosa Maria                1
# Viva Same Difference      1
# Name: Channel, Length: 6708, dtype: int64

# %%
spotify_youtube_data.describe()
# Out:
#                 Key      Loudness   Speechiness  Acousticness  \
# count  20247.000000  20247.000000  20247.000000  20247.000000
# mean       5.303502     -7.665131      0.096068      0.289146
# std        3.578103      4.616914      0.110200      0.286097
# min        0.000000    -46.251000      0.000000      0.000001
# 25%        2.000000     -8.833000      0.035600      0.043800
# 50%        5.000000     -6.540000      0.050500      0.190000
# 75%        8.000000     -4.939500      0.103000      0.472000
# max       11.000000      0.920000      0.964000      0.996000
#
#        Instrumentalness      Liveness       Valence         Tempo  \
# count      20247.000000  20247.000000  20247.000000  20247.000000
# mean           0.056003      0.191554      0.529305    120.604138
# std            0.193219      0.165545      0.245654     29.582294
# min            0.000000      0.014500      0.000000      0.000000
# 25%            0.000000      0.094000      0.339000     97.002000
# ...

# %%
#CHECK FOR THE CORRELATION BETWEEN DURATION AND VIEWS
plt.figure(figsize=(12,6))
sns.scatterplot(data = spotify_youtube_data, x = 'Duration_ms',
               y = 'Views',
               hue = 'Danceability')
sns.set_theme()

# %%
#CONVERT THE DURATION TO MINUTES

# %%
spotify_youtube_data['Duration_ms'] = round(spotify_youtube_data['Duration_ms']/60000, 2)

# %%
spotify_youtube_data['Duration_ms']
# Out:
# 0        3.71
# 1        3.34
# 2        3.59
# 3        3.90
# 4        5.68
#          ...
# 20713    1.58
# 20714    2.51
# 20715    2.28
# 20716    1.81
# 20717    3.02
# Name: Duration_ms, Length: 20247, dtype: float64

# %%
#RENAME THE COLUMN
spotify_youtube_data = spotify_youtube_data.rename(columns={'Duration_ms': 'Duration'})

# %%
spotify_youtube_data['Duration']
# Out:
# 0        3.71
# 1        3.34
# 2        3.59
# 3        3.90
# 4        5.68
#          ...
# 20713    1.58
# 20714    2.51
# 20715    2.28
# 20716    1.81
# 20717    3.02
# Name: Duration, Length: 20247, dtype: float64

# %%
plt.figure(figsize=(12,6))
sns.scatterplot(data = spotify_youtube_data,
               x = 'Duration', y = 'Stream')
# Out:
# <AxesSubplot:xlabel='Duration', ylabel='Stream'>

# %%
#REMOVE OUTLIERS FROM THE DATA
spotify_youtube_data.describe()
# Out:
#                 Key      Loudness   Speechiness  Acousticness  \
# count  20247.000000  20247.000000  20247.000000  20247.000000
# mean       5.303502     -7.665131      0.096068      0.289146
# std        3.578103      4.616914      0.110200      0.286097
# min        0.000000    -46.251000      0.000000      0.000001
# 25%        2.000000     -8.833000      0.035600      0.043800
# 50%        5.000000     -6.540000      0.050500      0.190000
# 75%        8.000000     -4.939500      0.103000      0.472000
# max       11.000000      0.920000      0.964000      0.996000
#
#        Instrumentalness      Liveness       Valence         Tempo  \
# count      20247.000000  20247.000000  20247.000000  20247.000000
# mean           0.056003      0.191554      0.529305    120.604138
# std            0.193219      0.165545      0.245654     29.582294
# min            0.000000      0.014500      0.000000      0.000000
# 25%            0.000000      0.094000      0.339000     97.002000
# ...

# %%
spotify_youtube_data[spotify_youtube_data['Album_type'] == 'album']['Duration'].mean()
# Out:
# 3.7689485565740806

# %%
max_duration_limit = spotify_youtube_data['Duration'].quantile(0.99)
max_duration_limit
# Out:
# 7.890800000000017

# %%
spotify_youtube_data[spotify_youtube_data['Duration'] > max_duration_limit]
# Out:
#                         Artist                                     Track  \
# 32                   Metallica            Master Of Puppets (Remastered)
# 527                  Green Day      Holiday / Boulevard Of Broken Dreams
# 1136               Soda Stereo  En La Ciudad De La Furia - Mtv Unplugged
# 1335   Wolfgang Amadeus Mozart                 Adagio In E Major, K. 261
# 1485         Shankar Mahadevan                       Shiv Tandav Stotram
# ...                        ...                                       ...
# 19951           Callejero Fino                        Pa Tra Rkt - Remix
# 19998               Marcianeke                             Ponle - Remix
# 20336              Mc Paiva Zs                         Set Wesley Alemão
# 20462            Tz Da Coronel                        Poesia Acústica 13
# 20600                    Oruam                        Poesia Acústica 13
#
#                                                Album   Album_type  \
# ...

# %%
min_duration_limit = spotify_youtube_data['Duration'].quantile(0.01)

# %%
spotify_youtube_data[spotify_youtube_data['Duration'] < min_duration_limit]
# Out:
#                    Artist                                              Track  \
# 982    Yuvan Shankar Raja                                     Kaadhal Endral
# 1117        John Williams                                 Carol Of The Bells
# 1118        John Williams  Somewhere In My Memory - Chorus & Orchestra Ve...
# 1188        Nat King Cole                                     Deck The Halls
# 1189        Nat King Cole                                   Joy To The World
# ...                   ...                                                ...
# 20650      Sleepy Penguin                        Magic Piano And White Noise
# 20651      Sleepy Penguin                        Colicky Baby Relaxing Tunes
# 20652      Sleepy Penguin                              Gentle Piano Melodies
# 20653      Sleepy Penguin                          Soothing Baby White Nosie
# 20654      Sleepy Penguin                     Soothing Piano And White Nosie
#
# ...

# %%
spotify_youtube_data = spotify_youtube_data[(spotify_youtube_data['Duration'] > min_duration_limit) & (spotify_youtube_data['Duration'] < max_duration_limit)]

# %%
spotify_youtube_data
# Out:
#             Artist                                          Track  \
# 0         Gorillaz                                 Feel Good Inc.
# 1         Gorillaz                                Rhinestone Eyes
# 2         Gorillaz  New Gold (Feat. Tame Impala And Bootie Brown)
# 3         Gorillaz                             On Melancholy Hill
# 4         Gorillaz                                 Clint Eastwood
# ...            ...                                            ...
# 20713  Sick Legend                           Just Dance Hardstyle
# 20714  Sick Legend                 Set Fire To The Rain Hardstyle
# 20715  Sick Legend                      Outside Hardstyle Sped Up
# 20716  Sick Legend                            Only Girl Hardstyle
# 20717  Sick Legend                             Miss You Hardstyle
#
#                                                Album Album_type Danceability  \
# 0                                         Demon Days      album            C
# ...

# %%
sns.set_style('white')
plt.figure(figsize=(12,6))
sns.barplot(x = 'Energy', y = 'Views',
           data = spotify_youtube_data)
plt.title("ENERGY AND VIEWS RELATIONSHIP", fontsize = 16)
sns.despine()

# %%
plt.figure(figsize = (10,7))
sns.scatterplot(x = 'Duration', y = 'Stream',
               data = spotify_youtube_data,
               hue = 'Energy')
sns.set_theme()
